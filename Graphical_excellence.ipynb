# %% [markdown]
# <a href="https://colab.research.google.com/github/Tobaho/Tobaho.github.io/blob/main/Graphical_excellence.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Graphical Excellence

# %% [markdown]
# John Snow's map of cholera outbreak shows graphical excellence in different ways. He was not a cartographer but he did well representing the graphical overview of the cholera outbreak. He made use of a street plan with black axes to show the streets that are being affected. He proposed a new hypothesis for how cholera was transmitted by making comparisons.

# %% [markdown]
# ![2430 (1).jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# The above graph demonstrates good graphical excellence. It shows the casualties which is plotted against the year of the ebola virus and the countries that were affected by ebola. This graph also shows the number of cases each year had and the number of people who died.

# %% [markdown]
# More information can be found here https://www.statista.com/chart/2430/the-deadliest-ever-ebola-virus-outbreak/
