# %% [markdown]
# <a href="https://colab.research.google.com/github/Tobaho/Tobaho.github.io/blob/main/SQL_JOINS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # SQL Joins

# %%
from google.colab import auth
auth.authenticate_user()
print('Authenticated')
# Out:
# Authenticated

# %% [markdown]
# I will be working on joins in this project.

# %%
# %%bigquery --project tobahodataviz
#
# SELECT name, property_type
# FROM `bigquery-public-data.austin_bikeshare.bikeshare_stations`
# LIMIT 50
# Out:
#                                                  name property_type
# 0                                          Pease Park          None
# 1                                     Republic Square          None
# 2                                    Waller & 6th St.          None
# 3                     Bullock Museum @ Congress & MLK          None
# 4                     State Capitol @ 14th & Colorado          None
# 5                             ACC - Rio Grande & 12th          None
# 6                            ACC - West & 12th Street          None
# 7               Republic Square @ Guadalupe & 4th St.          None
# 8                                    5th & San Marcos          None
# 9                                   Rainey @ River St          None
# 10                            Toomey Rd @ South Lamar          None
# 11                         East 7th & Pleasant Valley          None
# 12                            OFFICE/Main/Shop/Repair          None
# ...

# %%
# %%bigquery --project tobahodataviz
#
# with table as (
#   SELECT *
#   FROM bigquery-public-data.austin_bikeshare.bikeshare_stations
#   INNER JOIN bigquery-public-data.austin_bikeshare.bikeshare_trips
#   ON bikeshare_stations.name = bikeshare_trips.start_station_name
# )
#
# SELECT name AS Name, property_type AS PropertyType, AVG(duration_minutes) AS AveDurationMin
# FROM table
# GROUP BY name, property_type
# ORDER BY PropertyType
# Out:
#                                Name          PropertyType  AveDurationMin
# 0                  Zilker Park West                  None       27.168259
# 1           Toomey Rd @ South Lamar                  None       28.115798
# 2   State Capitol @ 14th & Colorado                  None       30.421842
# 3                  Waller & 6th St.                  None       23.265843
# 4                        Pease Park                  None       28.648889
# ..                              ...                   ...             ...
# 91                21st & University  undetermined_parking       18.341927
# 92                East 4th & Chicon  undetermined_parking       31.429918
# 93                   West & 6th St.  undetermined_parking       28.106093
# 94        East 6th & Pedernales St.  undetermined_parking       32.332959
# 95                    Nueces & 26th  undetermined_parking       16.805353
#
# [96 rows x 3 columns]

# %% [markdown]
# I have joined the property type table and the average duration minutes table. Now I am going to check if the average time on trips starting from 'parkland' is longer than trips starting from 'sidewalks'

# %%
# %%bigquery --project tobahodataviz
# with q as (
#   with table as (
#    SELECT *
#    FROM bigquery-public-data.austin_bikeshare.bikeshare_stations
#    INNER JOIN bigquery-public-data.austin_bikeshare.bikeshare_trips
#    ON bikeshare_stations.name = bikeshare_trips.start_station_name
#   )
#
#   SELECT name AS Name, property_type AS PropertyType, AVG(duration_minutes) AS AveDurationMin
#   FROM table
#   GROUP BY name, property_type
#   ORDER BY PropertyType
# )
# SELECT PropertyType, AVG(AveDurationMin) AS AveDurationMin
# FROM q
# GROUP BY PropertyType
# Out:
#            PropertyType  AveDurationMin
# 0                  None       27.089831
# 1  undetermined_parking       27.066346
# 2              sidewalk       34.582067
# 3    nonmetered_parking       50.633040
# 4          paid_parking       30.478807
# 5              parkland       39.996877
# 6                             33.502832

# %% [markdown]
# According to the table above, the trips from parkland were longer than the trips from sidewalk.
