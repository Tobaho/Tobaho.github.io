# %% [markdown]
# <a href="https://colab.research.google.com/github/Tobaho/Tobaho.github.io/blob/main/Box_plot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Distributions

# %% [markdown]
# In this project, i'll be making use of box plots and whisker plots. I'll start by importing my data.

# %%
df = pd.read_csv('https://raw.githubusercontent.com/nurfnick/Data_Viz/main/Activity_Dataset_V1.csv')
df.head()
# Out:
#    Unnamed: 0 activity_day    workout_type  distance  time  calories  \
# 0           0   2022-01-01       Freestyle      9.30    77       123
# 1           1   2022-01-01       Freestyle      3.44    96        55
# 2           2   2022-01-01  Indoor Cycling      6.34    85        33
# 3           3   2022-01-01         Walking      7.91    42        82
# 4           4   2022-01-01      Open Water      8.99    36       131
#
#    total_steps  avg_speed  avg_cadence  max_cadence  ... max_pace min_pace  \
# 0          NaN      18.88       168.54       138.30  ...      NaN      NaN
# 1          NaN      29.65       125.92       292.81  ...      NaN      NaN
# 2          NaN      17.85        81.93       323.69  ...      NaN      NaN
# 3       1571.0      22.10        29.63       180.16  ...    28:58    07:58
# 4          NaN      25.83        64.55       342.89  ...      NaN      NaN
#
#   avg_heart_rate  max_heart_rate  min_heart_rate  vo2_max(%)  aerobic(%)  \
# ...

# %%
import pandas as pd
import seaborn as sns
sns.set_style("dark")

# %%
ax = sns.boxplot(x=df['calories'])

# %% [markdown]
# I created a box plot for calories

# %% [markdown]
# I'll examine the calories burned by each excercise.

# %%
ax = sns.boxplot(x=df['calories'],y=df['workout_type'])

# %%
ax = sns.violinplot(data = df, x = 'calories', cut = 0)

# %%
sns.violinplot(data = df, y = 'workout_type', x = 'calories')
