# %% [markdown]
# <a href="https://colab.research.google.com/github/Tobaho/Tobaho.github.io/blob/main/Graphical_sophistication.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Graphical sophistication

# %% [markdown]
# I'll start this project by taking a look at this graph

# %% [markdown]
# https://viz.wtf/image/639589038118125568

# %% [markdown]
# ![tumblr_qm8kj9BEoD1sgh0voo1_640.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# The topic of this graph says "shoe color frequency". As a reader, I was expecting to see various shoe colors which were actually included in the graph. What caught my attention was the color black, but it's bar chart was made green.  For a second I was thrown off and I realized there were more mistakes/ errors. Blue was labelled white, red labelled blue, brown labelled red and so forth. Yellow was the only color labelled right. One can deduce that this graph does not display graphical integrity neither does it  show graphical excellence. Why did the writer mix up the colors and wrongly named them? This graph could have displayed graphical excellence if it was labelled right.

# %% [markdown]
# https://viz.wtf/image/633334089306537985

# %% [markdown]
# ![tumblr_qiguluFfhp1sgh0voo1_1280.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# This graph is a cute funny graphic. This graphic lacked quantitative skills. I see there are percentage that shows how much is spent on groceries in a week. It would have been better if there were actual numbers in the graphics.However, I liked how the writer portrayed the graphics using the size of the squares. Honestly, it's hard to decide if this graphics displayed graphical excellence. This graphic failedto show some qualities, so i'll say it does not display enough graphical excellence.
