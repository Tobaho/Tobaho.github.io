# %% [markdown]
# <a href="https://colab.research.google.com/github/Tobaho/Tobaho.github.io/blob/main/Evaluating_Final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Russia And Ukraine Export
# # Oluwatobi Afolabi
# #CPMSA 4313
# #Data Visualization
# # DR JACOB

# %% [markdown]
# ##How timely is my topic?
# Apparently, the Ukraine vs war has been going on for eight years according to Wikipedia. The invasion caught a lot of people’s attention which happened this year February 2022.
# Important details
# ##Summary on why the war started
# The last time the Russian military entered eastern Ukraine was in 2014. Putin stated that the invasion was only a defense of ethnic Russians living in the eastern Donbas region, many of whom have never supported the country's new pro-Western leadership. Russia's strongman leader (PUTIN) frequently mentions ethnic ties with Ukraine and warns against NATO's expansion eastward toward his borders. Putin asked that NATO rule out any new members from among the former Soviet republics — most notably, Ukraine — and that NATO forces pull back from positions in other countries bordering Russia before launching the present attack. The demand that any new members be barred was firmly rejected by the US and NATO.
# Many commentators believe Putin's goal is to destabilize Ukraine's current administration so that a new pro-Russian state can take its place.

# %% [markdown]
# ![pr 4.png](data:image/png;base64,...)

# %% [markdown]
# This graph above shows the Russian build up around Ukraine. Whenever I look at a graph for graphical excellence, there are three things I search for
# •	Well-structured data
# •	Serve a clear purpose, description, and exploration
# •	Statistical and verbal description of the data set is well defined
# This graph is an example of a grpah that shows grpahical excellence. In the  above image, there are two maps. One before build up and the other when the Russian troops were in position.
# Using the identity of the graph that the write provided us with, one can tell that the troop had a permanent unit around/borders of Russia. From the second graph, it is shown that the troopd in position were mainly in Belarus and around/boarders of Ukraine. There was little to no build up of russian troop before and neither are there troops in position in Russia. I am guessing because it's their country.
#
# This visualization helped to improve the article because, one can tell what the article is trying to say before readin the whole article. This visualization helps gives the reader a sense of understanding.

# %% [markdown]
# ![Pr 5.webp](data:image/webp;base64,...)

# %% [markdown]
# This graph is trying to tell us about the casualities that has occured in Ukraine. This graph is not the regular type graph that I see, this is somewhat different. I think this graph does not display enough graphical excellence. The title of the graph says "Estimated Russian Casualities".One could have assumed the the opeople who got injured or died(not knowing where). Looking down at this graph, you find the estimated number of people that were deployed to Ukraine. I believe the title should have been " Estimated Casualties of Russians deployed to Ukraine" or probably something shorter.
# The colors and the boxes are things I find misleading. I do understand the deep brown boxes, which signifies people who died and the light brown which signifies people who are wounded. However, I do not understand what the light brown with an open middle space, pinkish-brown, pinkish-brown with an open middle space represent.
#
# In as much as this graph does not satisfy graphical excellence to me, I think it helped the article in a way. I think the company/ reader tried to make a graph an easy one, for one to understand what is goin on by mere looking at it. The graph is a little well structured and I am certainn, One can get to understand few things about the happening of Russia and Ukraine.

# %% [markdown]
# ![pr 6.png](data:image/png;base64,...)

# %% [markdown]
# This is a graph that is detailed with pictures and naming/defining it. In as much as this graph looks like it does not display graphical excellence, I think the write did a great job. There is no way, one can draw 5520 vehicles. I like that the writer told us that an icon equals to 100 assests. There is not much to change about this graph, rather than it having a title.
#
# This graph is helpful because you can understand that the writer is trying to the readers the number of army personnels, battle tanks and vehicles. I can say with just 30 secons of looking at the graph above, one can deduce what the article will be about

# %% [markdown]
# ##Similarities

# %% [markdown]
# The three Visualization were trying to back an articles up and acting as a better means of helpingthe reader understand what it is going one. Giving the readers a better visual reprsentation.

# %% [markdown]
# ##Differences

# %% [markdown]
# The first image remains my favorite graph becasue it was well represented and it displayed graphical excellence. The third graph is a different from the frist two becasue "one icon was assigned to 100 assests". All three graphs are different and unique in their ways, but the second graph is a little poor.

# %% [markdown]
# ##Refrences

# %% [markdown]
# *   https://www.bbc.com/news/world-europe-60506682
# *   https://blog.datawrapper.de/data-vis-dispatch-march-1-2022/
# * https://www.washingtonpost.com/politics/2022/03/17/russias-fumbling-invasion-visualized/
